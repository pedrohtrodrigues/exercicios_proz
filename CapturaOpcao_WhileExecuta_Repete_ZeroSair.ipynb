# %% [markdown]
# <a href="https://colab.research.google.com/github/pedrohtrodrigues/exercicios_proz/blob/main/CapturaOpcao_WhileExecuta_Repete_ZeroSair.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Faça uma função calculadora que os números e as operações serão feitas pelo usuário. O código deve ficar rodando infinitamente até que o usuário escolha a opção de sair. No início, o programa mostrará a seguinte lista de operações:
#
# 1: Soma
# 2: Subtração
# 3: Multiplicação
# 4: Divisão
# 0: Sair
#
# Digite o número para a operação correspondente e caso o usuário introduza qualquer outro, o sistema deve mostrar a mensagem “Essa opção não existe” e voltar ao menu de opções.
#
# Após a seleção, o sistema deve pedir para o usuário inserir o primeiro e segundo valor, um de cada. Depois precisa executar a operação e mostrar o resultado na tela. Quando o usuário escolher a opção “Sair”, o sistema irá parar.
#
# É necessário que o sistema mostre as opções sempre que finalizar uma operação e mostrar o resultado.

# %%
def operacao (num1, num2, operador):
  if operador==1:
    return num1+num2;
  elif operador==2:
    return num1-num2;
  elif operador==3:
    return num1*num2;
  elif operador==4:
    return num1/num2;

print ("Insira uma opção: 1: Soma 2: Subtração 3: Multiplicação 4: Divisão ou 0: Sair ");
operador = int(input());

if operador==0:
    print ("Saindo do Sistema.");

while operador != 0:
  if operador not in (0, 1, 2, 3, 4):
    print ("Essa opção não existe.");
    print (" ");
    print ("Insira uma nova opção: 1: Soma 2: Subtração 3: Multiplicação 4: Divisão ou 0: Sair ");
    operador = int(input());
    print (" ");
    continue;
  elif operador in (1, 2, 3, 4):
    num1 = int(input("Insira o primeiro número: "));
    num2 = int(input("Insira o segundo número: "));
    resultado = operacao(num1, num2, operador);
    print ("Resultado é igual a: ", resultado);
    print (" ");
    print ("Insira uma nova opção: 1: Soma 2: Subtração 3: Multiplicação 4: Divisão ou 0: Sair ");
    operador = int(input());
# Out:
# Insira uma opção: 1: Soma 2: Subtração 3: Multiplicação 4: Divisão ou 0: Sair
# 0
# Saindo do Sistema.
